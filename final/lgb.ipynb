# %%
import lightgbm as lgb
import pandas as pd
import numpy as np

# %% [markdown]
# # dataset

# %%
train = pd.read_csv('./train_final.csv', engine='python')
test  = pd.read_csv('./test_final.csv', engine='python')

# %%
x_train = train.drop(['loan_status'], axis=1)
y_train = train['loan_status']

x_test = test.drop(['loan_status'], axis=1)
y_test = test['loan_status']

# %%
train.shape
# Out:
# (50000, 146)

# %%
x = pd.concat([x_train, x_test], axis=0)
y = pd.concat([y_train, y_test], axis=0)

data = pd.concat([x, y], axis=1)
data.shape
# Out:
# (100000, 146)

# %%
TRAIN_IDX = x_train.shape[0]
TEST_IDX = TRAIN_IDX + x_test.shape[0]

# %%
data.columns.to_list()
# Out:
# ['continuous_annual_inc',
#  'continuous_annual_inc_joint',
#  'continuous_delinq_2yrs',
#  'continuous_dti',
#  'continuous_dti_joint',
#  'continuous_fico_range_high',
#  'continuous_fico_range_low',
#  'continuous_funded_amnt',
#  'continuous_funded_amnt_inv',
#  'continuous_inq_last_6mths',
#  'continuous_installment',
#  'continuous_int_rate',
#  'continuous_last_fico_range_high',
#  'continuous_last_fico_range_low',
#  'continuous_loan_amnt',
#  'continuous_mths_since_last_delinq',
#  'continuous_mths_since_last_major_derog',
#  'continuous_mths_since_last_record',
#  'continuous_open_acc',
#  'continuous_pub_rec',
#  'discrete_addr_state_1_one_hot',
#  'discrete_addr_state_2_one_hot',
#  'discrete_addr_state_3_one_hot',
#  'discrete_addr_state_4_one_hot',
#  'discrete_addr_state_5_one_hot',
#  'discrete_addr_state_6_one_hot',
#  'discrete_addr_state_7_one_hot',
#  'discrete_addr_state_8_one_hot',
#  'discrete_addr_state_9_one_hot',
#  'discrete_addr_state_10_one_hot',
#  'discrete_addr_state_11_one_hot',
#  'discrete_addr_state_12_one_hot',
#  'discrete_addr_state_13_one_hot',
#  'discrete_addr_state_14_one_hot',
#  'discrete_addr_state_15_one_hot',
#  'discrete_addr_state_16_one_hot',
#  'discrete_addr_state_17_one_hot',
#  'discrete_addr_state_18_one_hot',
#  'discrete_addr_state_19_one_hot',
#  'discrete_addr_state_20_one_hot',
#  'discrete_addr_state_21_one_hot',
#  'discrete_addr_state_22_one_hot',
#  'discrete_addr_state_23_one_hot',
#  'discrete_addr_state_24_one_hot',
#  'discrete_addr_state_25_one_hot',
#  'discrete_addr_state_26_one_hot',
#  'discrete_addr_state_27_one_hot',
#  'discrete_addr_state_28_one_hot',
#  'discrete_addr_state_29_one_hot',
#  'discrete_addr_state_30_one_hot',
#  'discrete_addr_state_31_one_hot',
#  'discrete_addr_state_32_one_hot',
#  'discrete_addr_state_33_one_hot',
#  'discrete_addr_state_34_one_hot',
#  'discrete_addr_state_35_one_hot',
#  'discrete_addr_state_36_one_hot',
#  'discrete_addr_state_37_one_hot',
#  'discrete_addr_state_38_one_hot',
#  'discrete_addr_state_39_one_hot',
#  'discrete_addr_state_40_one_hot',
#  'discrete_addr_state_41_one_hot',
#  'discrete_addr_state_42_one_hot',
#  'discrete_addr_state_43_one_hot',
#  'discrete_addr_state_44_one_hot',
#  'discrete_addr_state_45_one_hot',
#  'discrete_addr_state_46_one_hot',
#  'discrete_addr_state_47_one_hot',
#  'discrete_addr_state_48_one_hot',
#  'discrete_addr_state_49_one_hot',
#  'discrete_application_type_1_one_hot',
#  'discrete_application_type_2_one_hot',
#  'discrete_emp_length_1_one_hot',
#  'discrete_emp_length_2_one_hot',
#  'discrete_emp_length_3_one_hot',
#  'discrete_emp_length_4_one_hot',
#  'discrete_emp_length_5_one_hot',
#  'discrete_emp_length_6_one_hot',
#  'discrete_emp_length_7_one_hot',
#  'discrete_emp_length_8_one_hot',
#  'discrete_emp_length_9_one_hot',
#  'discrete_emp_length_10_one_hot',
#  'discrete_emp_length_11_one_hot',
#  'discrete_emp_length_12_one_hot',
#  'discrete_grade_1_one_hot',
#  'discrete_grade_2_one_hot',
#  'discrete_grade_3_one_hot',
#  'discrete_grade_4_one_hot',
#  'discrete_grade_5_one_hot',
#  'discrete_grade_6_one_hot',
#  'discrete_grade_7_one_hot',
#  'discrete_home_ownership_1_one_hot',
#  'discrete_home_ownership_2_one_hot',
#  'discrete_home_ownership_3_one_hot',
#  'discrete_home_ownership_4_one_hot',
#  'discrete_policy_code_1_one_hot',
#  'discrete_purpose_1_one_hot',
#  'discrete_purpose_2_one_hot',
#  'discrete_purpose_3_one_hot',
#  'discrete_purpose_4_one_hot',
#  'discrete_purpose_5_one_hot',
#  'discrete_purpose_6_one_hot',
#  'discrete_purpose_7_one_hot',
#  'discrete_purpose_8_one_hot',
#  'discrete_purpose_9_one_hot',
#  'discrete_purpose_10_one_hot',
#  'discrete_purpose_11_one_hot',
#  'discrete_purpose_12_one_hot',
#  'discrete_pymnt_plan_1_one_hot',
#  'discrete_sub_grade_1_one_hot',
#  'discrete_sub_grade_2_one_hot',
#  'discrete_sub_grade_3_one_hot',
#  'discrete_sub_grade_4_one_hot',
#  'discrete_sub_grade_5_one_hot',
#  'discrete_sub_grade_6_one_hot',
#  'discrete_sub_grade_7_one_hot',
#  'discrete_sub_grade_8_one_hot',
#  'discrete_sub_grade_9_one_hot',
#  'discrete_sub_grade_10_one_hot',
#  'discrete_sub_grade_11_one_hot',
#  'discrete_sub_grade_12_one_hot',
#  'discrete_sub_grade_13_one_hot',
#  'discrete_sub_grade_14_one_hot',
#  'discrete_sub_grade_15_one_hot',
#  'discrete_sub_grade_16_one_hot',
#  'discrete_sub_grade_17_one_hot',
#  'discrete_sub_grade_18_one_hot',
#  'discrete_sub_grade_19_one_hot',
#  'discrete_sub_grade_20_one_hot',
#  'discrete_sub_grade_21_one_hot',
#  'discrete_sub_grade_22_one_hot',
#  'discrete_sub_grade_23_one_hot',
#  'discrete_sub_grade_24_one_hot',
#  'discrete_sub_grade_25_one_hot',
#  'discrete_sub_grade_26_one_hot',
#  'discrete_sub_grade_27_one_hot',
#  'discrete_sub_grade_28_one_hot',
#  'discrete_sub_grade_29_one_hot',
#  'discrete_sub_grade_30_one_hot',
#  'discrete_sub_grade_31_one_hot',
#  'discrete_sub_grade_32_one_hot',
#  'discrete_sub_grade_33_one_hot',
#  'discrete_sub_grade_34_one_hot',
#  'discrete_sub_grade_35_one_hot',
#  'discrete_term_1_one_hot',
#  'discrete_term_2_one_hot',
#  'loan_status']

# %% [markdown]
# ## basic data manipulation

# %%
data['loan_status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['loan_status'].value_counts()
# Out:
# 1    80014
# 0    19986
# Name: loan_status, dtype: int64

# %% [markdown]
# # Tree based models

# %%
train = data.iloc[:TRAIN_IDX, :]
test = data.iloc[TRAIN_IDX:TEST_IDX, :]

# %%
import lightgbm as lgb
train_dataset = lgb.Dataset(train.drop(columns='loan_status'), train['loan_status'])
test_dataset = lgb.Dataset(test.drop(columns='loan_status'), test['loan_status'])

# %%
param = {'num_leaves': 31, 'objective': 'binary', 'metric':'binary_error'}
num_round = 2000

# %%
# model = lgb.train(param, train_dataset, num_boost_round=num_round, valid_sets=[train_dataset, test_dataset])

# %% [markdown]
# ## wrapper

# %%
import io
import multiprocessing
from contextlib import redirect_stdout
from copy import deepcopy
from dataclasses import dataclass, asdict
import hyperopt.pyll
from hyperopt import fmin, tpe, hp
import numpy as np
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
import torch

import copy
cpu_count = 12
use_gpu = False
@dataclass
class LGBOpt:
    num_threads: any = hp.choice('num_threads', [cpu_count])
    num_leaves: any = hp.choice('num_leaves', [4, 6, 12, 20, 32])
    metric: any = hp.choice('metric', ['binary_error'])
    num_round: any = hp.choice('num_round', [2000, 4000])
    objective: any = hp.choice('objective', ['binary'])
    learning_rate: any = hp.uniform('learning_rate', 0.01, 0.1)
    feature_fraction: any = hp.uniform('feature_fraction', 0.5, 1.0)
    bagging_fraction: any = hp.uniform('bagging_fraction', 0.8, 1.0)
#     device_type: any = hp.choice('device_tpye', ['gpu']) if use_gpu else hp.choice('device_type',
#                                                                                    ['cpu'])
    boosting: any = hp.choice('boosting', ['gbdt'])
#     extra_trees: any = hp.choice('extra_tress', [False, True])
#     drop_rate: any = hp.uniform('drop_rate', 0, 0.2)
#     uniform_drop: any = hp.choice('uniform_drop', [True, False])
    lambda_l1: any = hp.uniform('lambda_l1', 0, 10)  # TODO: Check range
    lambda_l2: any = hp.uniform('lambda_l2', 0, 10)  # TODO: Check range
#     min_gain_to_split: any = hp.uniform('min_gain_to_split', 0, 1)  # TODO: Check range
    min_data_in_bin = hp.choice('min_data_in_bin', [3, 5, 10, 15, 20, 50])

    @staticmethod
    def get_common_params():
        return {'num_thread': 4, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary',
                'num_round': 1000, 'learning_rate': 0.01, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
class FitterBase(object):
    def __init__(self, label, metric, max_eval=100, opt=None):
        self.label = label
        self.metric = metric
        self.opt_params = dict()
        self.max_eval = max_eval
        self.opt = opt

    def get_loss(self, y, y_pred):
        if self.metric == 'error':
            return 1 - accuracy_score(y, y_pred)
        elif self.metric == 'precision':
            return 1 - precision_score(y, y_pred)
        elif self.metric == 'recall':
            return 1 - recall_score(y, y_pred)
        elif self.metric == 'macro_f1':
            return 1 - f1_score(y, y_pred, average='macro')
        elif self.metric == 'micro_f1':
            return 1 - f1_score(y, y_pred, average='micro')
        elif self.metric == 'auc':  # TODO: Add a warning checking if y_predict is all [0, 1], it should be probability
            return 1 - roc_auc_score(y, y_pred)
        else:
            raise Exception("Not implemented yet.")

# %%
class LGBFitter(FitterBase):
    def __init__(self, label='label', metric='error', opt: LGBOpt = None, max_eval=100):
        super(LGBFitter, self).__init__(label, metric, max_eval)
        if opt is not None:
            self.opt = opt
        else:
            self.opt = LGBOpt()
        self.best_round = None
        self.clf = None

    def train(self, train_df, eval_df, params=None, use_best_eval=True):
        self.best_round = None
        dtrain = lgb.Dataset(train_df.drop(columns=[self.label]), train_df[self.label])
        deval = lgb.Dataset(eval_df.drop(columns=[self.label]), eval_df[self.label])
        evallist = [dtrain, deval]
        if params is None:
            use_params = deepcopy(self.opt_params)
        else:
            use_params = deepcopy(params)

        num_round = use_params.pop('num_round')
        if use_best_eval:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            min_error = np.inf
            min_index = 0
            for idx in range(len(output) - 1):
                if len(output[idx].split("\t")) == 3:
                    temp = float(output[idx].split("\t")[2].split(":")[1])
                    if min_error > temp:
                        min_error = temp
                        min_index = int(output[idx].split("\t")[0][1:-1])
            print("The minimum is attained in round %d" % (min_index + 1))
            self.best_round = min_index + 1
            return output
        else:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            self.best_round = num_round
            return output

    def search(self, train_df, eval_df, use_best_eval=True):
        self.opt_params = dict()

        def train_impl(params):
            self.train(train_df, eval_df, params, use_best_eval)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            return self.get_loss(eval_df[self.label], y_pred)

        self.opt_params = fmin(train_impl, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def search_k_fold(self, k_fold, data, use_best_eval=True):
        self.opt_params = dict()

        def train_impl_nfold(params):
            loss = list()
             
            print(params)
            for train_id, eval_id in k_fold.split(data):
                train_df = data.loc[train_id]
                eval_df = data.loc[eval_id]
                self.train(train_df, eval_df, params, use_best_eval)
                if self.metric == 'auc':
                    y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
                else:
                    y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                               num_iteration=self.best_round) > 0.5).astype(int)
                loss.append(self.get_loss(eval_df[self.label], y_pred))
            print(100*np.mean(loss), '%')
            return np.mean(loss)

        self.opt_params = fmin(train_impl_nfold, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def train_k_fold(self, k_fold, train_data, test_data, params=None, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        test_acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        test_preds = None
        
        if drop_test_y:
            dtest = test_data.drop(columns=self.label)
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            self.train(train_df, eval_df, params, use_best_eval)
            models.append(copy.deepcopy(self.clf))
            train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), num_iteration=self.best_round)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            acc_result.append(self.get_loss(eval_df[self.label], y_pred))
            test_pred = self.clf.predict(dtest, num_iteration=self.best_round)
        
            # save k-fold test_preds
            test_pred = np.expand_dims(test_pred, axis=0)
            if test_preds is None:
                test_preds = test_pred
            else:
                test_preds = np.concatenate((test_preds, test_pred), axis=0)
        return train_pred, test_preds, acc_result, models

# %% [markdown]
# ## train

# %%
fitter = LGBFitter(label='loan_status')

from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)

# %%
import numpy as np
num_leaves = [6, 12, 20, 32, 48, 64, 80, 96, 127]
# num_leaves = [i for i in range(6, 14, 2)]
for num_leave in num_leaves:
# lrs = [0.005, 0.01, 0.02]
# for lr in lrs:
# fractions = [0.6, 0.7, 0.8, 0.9, 1.0]
# for fraction in fractions:
# l1s = np.linspace(0, 2, num=20)
# for l1 in l1s:
    params = {'num_thread': 12, 'num_leaves': num_leave, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 
          'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
    print(params)
    _, _, error_rate, _ = fitter.train_k_fold(kfold, train, test, params = params)
    print(100 * np.mean(error_rate), '%')
# Out:
# {'num_thread': 12, 'num_leaves': 6, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 504
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 489
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 844
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 620
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 513
# Finished loading model, total used 1000 iterations
# 7.990000000000001 %
# {'num_thread': 12, 'num_leaves': 12, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 434
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 540
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 450
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 269
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 259
# Finished loading model, total used 1000 iterations
# 8.018 %
# {'num_thread': 12, 'num_leaves': 20, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 406
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 194
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 266
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 291
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 248
# Finished loading model, total used 1000 iterations
# 8.010000000000002 %
# {'num_thread': 12, 'num_leaves': 32, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 478
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 219
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 314
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 176
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 188
# Finished loading model, total used 1000 iterations
# 8.088000000000003 %
# {'num_thread': 12, 'num_leaves': 48, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 419
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 189
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 200
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 170
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 197
# Finished loading model, total used 1000 iterations
# 8.108 %
# {'num_thread': 12, 'num_leaves': 64, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 194
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 242
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 234
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 170
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 195
# Finished loading model, total used 1000 iterations
# 8.153999999999998 %
# {'num_thread': 12, 'num_leaves': 80, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 339
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 188
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 219
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 172
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 210
# Finished loading model, total used 1000 iterations
# 8.196 %
# {'num_thread': 12, 'num_leaves': 96, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-5b5ca64a85fb> in <module>
#      12           'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
#      13     print(params)
# ---> 14     _, _, error_rate, _ = fitter.train_k_fold(kfold, train, test, params = params)
#      15     print(100 * np.mean(error_rate), '%')
#
# <ipython-input-16-98e3489b1cf8> in train_k_fold(self, k_fold, train_data, test_data, params, drop_test_y, use_best_eval)
#      96             train_df = train_data.loc[train_id]
#      97             eval_df = train_data.loc[eval_id]
# ---> 98             self.train(train_df, eval_df, params, use_best_eval)
#      99             models.append(copy.deepcopy(self.clf))
#     100             train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), num_iteration=self.best_round)
#
# <ipython-input-16-98e3489b1cf8> in train(self, train_df, eval_df, params, use_best_eval)
#      22         if use_best_eval:
#      23             with io.StringIO() as buf, redirect_stdout(buf):
# ---> 24                 self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
#      25                 output = buf.getvalue().split("\n")
#      26             min_error = np.inf
#
# C:\Users\shpf_\miniconda3\envs\py37_torch\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     250                                     evaluation_result_list=None))
#     251
# --> 252         booster.update(fobj=fobj)
#     253
#     254         evaluation_result_list = []
#
# C:\Users\shpf_\miniconda3\envs\py37_torch\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    2458             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    2459                 self.handle,
# -> 2460                 ctypes.byref(is_finished)))
#    2461             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    2462             return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# # 当前最优参数，做test

# %%
#########################################################################################################
#                                         boosting = 'gbdt'                                             #
#########################################################################################################
# 7.983999999999999 %  from self
# Vote           8.204%
# mean, Predict, 8.206000000000003%
params1 = {'num_thread': 12, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary', 
          'num_round': 4000, 'learning_rate': 0.004, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
# 7.847999999999999 % from hyperopt
# Vote           8.177999999999997%
# mean, Predict, 8.189999999999998%
params2 = {'bagging_fraction': 0.936883991179611, 'boosting': 'goss', 'device_type': 'cpu', 
          'drop_rate': 0.11852930241041167, 'extra_trees': True, 'feature_fraction': 0.5227806161720856, 
          'lambda_l1': 4.3254509530619, 'lambda_l2': 2.5119994536346746, 'learning_rate': 0.0608188253086666, 
          'metric': 'binary_error', 'min_gain_to_split': 0.2888168506543208, 'num_leaves': 6, 
          'num_round': 2000, 'num_threads': 12, 'objective': 'binary', 'uniform_drop': False}

# %%
# 7.962 % plus regularization
# Vote           8.225999999999999%
# mean, Predict, 8.238000000000001%
params3 = {'num_thread': 12, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary', 'num_round': 200, 
          'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 
          'lambda_l1': 0.6063157894736843, 'lambda_l2': 0.26}

# %%
#########################################################################################################
#                                         boosting = 'goss'                                             #
#########################################################################################################
# 7.928000000000002 %
# Vote           8.187999999999995
# mean, Predict, 8.206000000000003
params4 = {'num_thread': 12, 'num_leaves': 8, 'boosting': 'goss', 'metric': 'binary', 'objective': 'binary', 
          'num_round': 4000, 'learning_rate': 0.005, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
#########################################################################################################
#                                         boosting = 'dart'                                             #
#########################################################################################################
# 7.990000000000001 %
# Vote           
# mean, Predict, 

params5 = {'num_thread': 12, 'num_leaves': 6, 'boosting': 'dart', 'metric': 'binary', 
           'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 
           'bagging_fraction': 0.8}

# %%
#########################################################################################################
#                                         merge                                                         #
#########################################################################################################
test_preds = None
params = [params1, params4, params5]
for i in range(len(params)):
    print(params[i])
    _, test_pred, error_rate, _ = fitter.train_k_fold(kfold, train, test, params = params[i])
    print(100 * np.mean(error_rate), '%')
    
    if test_preds is None:
        test_preds = test_pred
    else:
        test_preds = np.concatenate((test_preds, test_pred), axis=0)

print(test_preds.shape)
# Out:
# {'num_thread': 12, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary', 'num_round': 4000, 'learning_rate': 0.004, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 2143
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 2194
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 2226
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 3538
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 1695
# Finished loading model, total used 4000 iterations
# 7.983999999999999 %
# {'num_thread': 12, 'num_leaves': 8, 'boosting': 'goss', 'metric': 'binary', 'objective': 'binary', 'num_round': 4000, 'learning_rate': 0.005, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 3183
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 2095
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 2771
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 3827
# Finished loading model, total used 4000 iterations
# The minimum is attained in round 2231
# Finished loading model, total used 4000 iterations
# 7.928000000000002 %
# {'num_thread': 12, 'num_leaves': 6, 'boosting': 'dart', 'metric': 'binary', 'objective': 'binary', 'num_round': 1000, 'learning_rate': 0.1, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}
# The minimum is attained in round 504
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 489
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 844
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 620
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 513
# Finished loading model, total used 1000 iterations
# 7.990000000000001 %
# (15, 50000)

# %%
# test
def test_error(test, test_preds, label='loan_status', flag=True):
    """
    flag: True,      , Vote
        : False, mean, Predict
    """
    loss = FitterBase(label=label, metric='error')
    test_label = test[label]
    threshold = np.ceil(test_preds.shape[0] / 2).astype('int')
#     print(threshold)
    if flag:
        print('Vote')
        preds = (test_preds > 0.5).astype(int)
        pred = (np.sum(preds, axis=0) > threshold).astype(int) 
    else:
        print('mean, Predict')
        pred = (np.mean(test_preds, axis=0) > 0.5).astype(int)
    return 100 * loss.get_loss(test_label, pred)

print(test_error(test, test_preds))    
print(test_error(test, test_preds, flag=False))
# Out:
# Vote
# 8.179999999999998
# mean, Predict
# 8.153999999999995

# %% [markdown]
# # hyperopt

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)

opt = LGBOpt()
fitter = LGBFitter(label='loan_status', opt=opt)

fitter.search_k_fold(kfold, train, use_best_eval=True)
# _, _, error_rate, _ = fitter.train_k_fold(kfold, train, test, params=None)
# print(params)
# print(100 * np.mean(error_rate), '%')
# Out:
# {'bagging_fraction': 0.9019749724390823, 'boosting': 'gbdt', 'feature_fraction': 0.571313880484396, 'lambda_l1': 2.9227308946837747, 'lambda_l2': 1.8184290733490016, 'learning_rate': 0.017191306108113986, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 1083
# The minimum is attained in round 3056
# The minimum is attained in round 554
# The minimum is attained in round 2626
# The minimum is attained in round 2555
# 7.956
# %
# {'bagging_fraction': 0.9508332588128748, 'boosting': 'gbdt', 'feature_fraction': 0.6505247362327948, 'lambda_l1': 0.21198503599431207, 'lambda_l2': 1.39485205542353, 'learning_rate': 0.029209984190545615, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 623
# The minimum is attained in round 474
# The minimum is attained in round 242
# The minimum is attained in round 1709
# The minimum is attained in round 1210
# 7.937999999999998
# %
# {'bagging_fraction': 0.8698720528693045, 'boosting': 'gbdt', 'feature_fraction': 0.9646585402617058, 'lambda_l1': 3.701407467303989, 'lambda_l2': 9.942392259841228, 'learning_rate': 0.018392760838147226, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 146
# The minimum is attained in round 141
# The minimum is attained in round 104
# The minimum is attained in round 1389
# The minimum is attained in round 302
# 7.956
# %
# {'bagging_fraction': 0.9053051055046956, 'boosting': 'gbdt', 'feature_fraction': 0.7052920118893159, 'lambda_l1': 1.4786107644398194, 'lambda_l2': 3.189467719506418, 'learning_rate': 0.06781592473064231, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 65
# The minimum is attained in round 86
# The minimum is attained in round 31
# The minimum is attained in round 138
# The minimum is attained in round 213
# 8.006000000000002
# %
# {'bagging_fraction': 0.8530506103949269, 'boosting': 'gbdt', 'feature_fraction': 0.7998582817635779, 'lambda_l1': 0.08560739442234011, 'lambda_l2': 1.548663488961075, 'learning_rate': 0.0411230886077042, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 54
# The minimum is attained in round 63
# The minimum is attained in round 46
# The minimum is attained in round 560
# The minimum is attained in round 114
# 7.980000000000001
# %
# {'bagging_fraction': 0.9566341007602439, 'boosting': 'gbdt', 'feature_fraction': 0.5977923964444357, 'lambda_l1': 0.23122037060921863, 'lambda_l2': 4.049334577299657, 'learning_rate': 0.0696604636255816, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 54
# The minimum is attained in round 57
# The minimum is attained in round 42
# The minimum is attained in round 202
# The minimum is attained in round 84
# 8.04
# %
# {'bagging_fraction': 0.8533865177315849, 'boosting': 'gbdt', 'feature_fraction': 0.5603225874186952, 'lambda_l1': 5.578225939479652, 'lambda_l2': 7.027987414465871, 'learning_rate': 0.029487394530075865, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 206
# The minimum is attained in round 99
# The minimum is attained in round 65
# The minimum is attained in round 813
# The minimum is attained in round 764
# 7.968000000000002
# %
# {'bagging_fraction': 0.9624947673464409, 'boosting': 'gbdt', 'feature_fraction': 0.9387060351826645, 'lambda_l1': 2.085706338134259, 'lambda_l2': 7.592680574817252, 'learning_rate': 0.05407069544791596, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 228
# The minimum is attained in round 55
# The minimum is attained in round 143
# The minimum is attained in round 585
# The minimum is attained in round 77
# 7.962
# %
# {'bagging_fraction': 0.9102855993699241, 'boosting': 'gbdt', 'feature_fraction': 0.808693155937112, 'lambda_l1': 8.443214957672417, 'lambda_l2': 6.485926947545827, 'learning_rate': 0.07665878800378793, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 170
# The minimum is attained in round 46
# The minimum is attained in round 67
# The minimum is attained in round 517
# The minimum is attained in round 62
# 7.986
# %
# {'bagging_fraction': 0.8963781536951525, 'boosting': 'gbdt', 'feature_fraction': 0.7249140918241592, 'lambda_l1': 2.692501376342955, 'lambda_l2': 0.47989175474300594, 'learning_rate': 0.015531119035571455, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 1200
# The minimum is attained in round 1032
# The minimum is attained in round 921
# The minimum is attained in round 1927
# The minimum is attained in round 384
# 7.960000000000001
# %
# {'bagging_fraction': 0.9437704979769561, 'boosting': 'gbdt', 'feature_fraction': 0.8157238542762999, 'lambda_l1': 7.714896243501991, 'lambda_l2': 2.398262426778117, 'learning_rate': 0.015418686289112393, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 782
# The minimum is attained in round 717
# The minimum is attained in round 627
# The minimum is attained in round 1921
# The minimum is attained in round 1236
# 7.960000000000001
# %
# {'bagging_fraction': 0.8429421779041436, 'boosting': 'gbdt', 'feature_fraction': 0.5137285236812251, 'lambda_l1': 2.060654224362052, 'lambda_l2': 0.8953186448147465, 'learning_rate': 0.09769837089242839, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 107
# The minimum is attained in round 317
# The minimum is attained in round 150
# The minimum is attained in round 788
# The minimum is attained in round 435
# 7.926000000000003
# %
# {'bagging_fraction': 0.9577854269291997, 'boosting': 'gbdt', 'feature_fraction': 0.9821060188947599, 'lambda_l1': 9.516929446127417, 'lambda_l2': 8.469070508147716, 'learning_rate': 0.06039799967957273, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 93
# The minimum is attained in round 109
# The minimum is attained in round 439
# The minimum is attained in round 410
# The minimum is attained in round 312
# 7.992000000000002
# %
# {'bagging_fraction': 0.92303345242991, 'boosting': 'gbdt', 'feature_fraction': 0.6747249726396082, 'lambda_l1': 8.075020755571774, 'lambda_l2': 0.6595739637016784, 'learning_rate': 0.026902104320312925, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 348
# The minimum is attained in round 143
# The minimum is attained in round 491
# The minimum is attained in round 1233
# The minimum is attained in round 184
# 7.967999999999997
# %
# {'bagging_fraction': 0.852143388266614, 'boosting': 'gbdt', 'feature_fraction': 0.9815587932042609, 'lambda_l1': 3.6061299200975236, 'lambda_l2': 2.384144393548148, 'learning_rate': 0.010381333775843372, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 1150
# The minimum is attained in round 3028
# The minimum is attained in round 1447
# The minimum is attained in round 2108
# The minimum is attained in round 3557
# 7.958000000000001
# %
# {'bagging_fraction': 0.9028699941616721, 'boosting': 'gbdt', 'feature_fraction': 0.6842401695621989, 'lambda_l1': 0.140610124887377, 'lambda_l2': 4.138753696382195, 'learning_rate': 0.034665657287624864, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 108
# The minimum is attained in round 85
# The minimum is attained in round 224
# The minimum is attained in round 1437
# The minimum is attained in round 145
# 7.969999999999999
# %
# {'bagging_fraction': 0.8142829507730537, 'boosting': 'gbdt', 'feature_fraction': 0.5440345665668413, 'lambda_l1': 7.923123612242734, 'lambda_l2': 3.069022442602163, 'learning_rate': 0.027577222072949374, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 627
# The minimum is attained in round 473
# The minimum is attained in round 342
# The minimum is attained in round 691
# The minimum is attained in round 1627
# 7.973999999999999
# %
# {'bagging_fraction': 0.9153614776591379, 'boosting': 'gbdt', 'feature_fraction': 0.7859247464291199, 'lambda_l1': 7.568362221201076, 'lambda_l2': 5.391790944188026, 'learning_rate': 0.08454057500834625, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 50
# The minimum is attained in round 49
# The minimum is attained in round 23
# The minimum is attained in round 206
# The minimum is attained in round 91
# 8.005999999999998
# %
# {'bagging_fraction': 0.9485959669482315, 'boosting': 'gbdt', 'feature_fraction': 0.9815182723885643, 'lambda_l1': 9.484405636907251, 'lambda_l2': 3.8387028694168004, 'learning_rate': 0.012150064853637817, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 626
# The minimum is attained in round 307
# The minimum is attained in round 1493
# The minimum is attained in round 1576
# The minimum is attained in round 477
# 7.948000000000002
# %
# {'bagging_fraction': 0.8661511938638264, 'boosting': 'gbdt', 'feature_fraction': 0.5345520233134569, 'lambda_l1': 3.678677898839754, 'lambda_l2': 7.343290399935979, 'learning_rate': 0.06265431473983415, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 64
# The minimum is attained in round 60
# The minimum is attained in round 134
# The minimum is attained in round 581
# The minimum is attained in round 110
# 7.998000000000001
# %
# {'bagging_fraction': 0.9974619352064875, 'boosting': 'gbdt', 'feature_fraction': 0.622985705456263, 'lambda_l1': 1.1672208240642976, 'lambda_l2': 0.11872913792469153, 'learning_rate': 0.09467135949962313, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 502
# The minimum is attained in round 320
# The minimum is attained in round 396
# The minimum is attained in round 371
# The minimum is attained in round 683
# 7.912
# %
# {'bagging_fraction': 0.9991383342510026, 'boosting': 'gbdt', 'feature_fraction': 0.5019352123830692, 'lambda_l1': 5.477301959161808, 'lambda_l2': 0.003053027910531775, 'learning_rate': 0.09822909737135516, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 156
# The minimum is attained in round 219
# The minimum is attained in round 153
# The minimum is attained in round 645
# The minimum is attained in round 636
# 7.932000000000001
# %
# {'bagging_fraction': 0.8109532933792166, 'boosting': 'gbdt', 'feature_fraction': 0.6239789204380648, 'lambda_l1': 1.3028217050572921, 'lambda_l2': 0.1369455259306145, 'learning_rate': 0.09941644123998278, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 352
# The minimum is attained in round 335
# The minimum is attained in round 128
# The minimum is attained in round 312
# The minimum is attained in round 756
# 7.918
# %
# {'bagging_fraction': 0.8059266748825954, 'boosting': 'gbdt', 'feature_fraction': 0.6257804362218463, 'lambda_l1': 1.1259100293617519, 'lambda_l2': 0.10532998210340941, 'learning_rate': 0.08870001586780411, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 567
# The minimum is attained in round 346
# The minimum is attained in round 209
# The minimum is attained in round 1378
# The minimum is attained in round 953
# 7.931999999999999
# %
# {'bagging_fraction': 0.9957299282262743, 'boosting': 'gbdt', 'feature_fraction': 0.8802711817040552, 'lambda_l1': 6.462552389224883, 'lambda_l2': 5.193822142806815, 'learning_rate': 0.0909445518786253, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 145
# The minimum is attained in round 117
# The minimum is attained in round 116
# The minimum is attained in round 1835
# The minimum is attained in round 828
# 7.956
# %
# {'bagging_fraction': 0.8242692072191454, 'boosting': 'gbdt', 'feature_fraction': 0.6171933444502734, 'lambda_l1': 1.034691217967022, 'lambda_l2': 9.955369829444852, 'learning_rate': 0.0817916121289929, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 1121
# The minimum is attained in round 120
# The minimum is attained in round 357
# The minimum is attained in round 1841
# The minimum is attained in round 1429
# 7.906000000000002
# %
# {'bagging_fraction': 0.8291231672169844, 'boosting': 'gbdt', 'feature_fraction': 0.7572026163007937, 'lambda_l1': 4.666176497677883, 'lambda_l2': 9.940423335481519, 'learning_rate': 0.08191277440892435, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 248
# The minimum is attained in round 393
# The minimum is attained in round 157
# The minimum is attained in round 1405
# The minimum is attained in round 702
# 7.926000000000003
# %
# {'bagging_fraction': 0.9806243711269305, 'boosting': 'gbdt', 'feature_fraction': 0.6025732268076784, 'lambda_l1': 0.8321198559374245, 'lambda_l2': 9.002908369869532, 'learning_rate': 0.07487983932684343, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 133
# The minimum is attained in round 132
# The minimum is attained in round 327
# The minimum is attained in round 1691
# The minimum is attained in round 697
# 7.931999999999999
# %
# {'bagging_fraction': 0.9359373293926333, 'boosting': 'gbdt', 'feature_fraction': 0.5742326721678649, 'lambda_l1': 2.8400437242230216, 'lambda_l2': 6.02762189570353, 'learning_rate': 0.09222939368314742, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 77
# The minimum is attained in round 27
# The minimum is attained in round 20
# The minimum is attained in round 326
# The minimum is attained in round 114
# 8.016000000000002
# %
# {'bagging_fraction': 0.8794163084087208, 'boosting': 'gbdt', 'feature_fraction': 0.6526107120207943, 'lambda_l1': 4.583338218641576, 'lambda_l2': 9.01960453204971, 'learning_rate': 0.04975204167821987, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 745
# The minimum is attained in round 689
# The minimum is attained in round 230
# The minimum is attained in round 1667
# The minimum is attained in round 1234
# 7.951999999999996
# %
# {'bagging_fraction': 0.9850871319012533, 'boosting': 'gbdt', 'feature_fraction': 0.7284086360399753, 'lambda_l1': 0.6707629944172561, 'lambda_l2': 4.843574086115921, 'learning_rate': 0.08210600413302518, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 1075
# The minimum is attained in round 401
# The minimum is attained in round 255
# The minimum is attained in round 447
# The minimum is attained in round 935
# 7.931999999999999
# %
# {'bagging_fraction': 0.8873181103786089, 'boosting': 'gbdt', 'feature_fraction': 0.8630529671263951, 'lambda_l1': 1.8338517738952698, 'lambda_l2': 7.824552985688582, 'learning_rate': 0.0746229838249961, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 55
# The minimum is attained in round 38
# The minimum is attained in round 28
# The minimum is attained in round 147
# The minimum is attained in round 231
# 8.001999999999999
# %
# {'bagging_fraction': 0.8320270758328717, 'boosting': 'gbdt', 'feature_fraction': 0.6575102163727177, 'lambda_l1': 3.16360758736851, 'lambda_l2': 9.877254854865539, 'learning_rate': 0.09168421346257914, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 410
# The minimum is attained in round 357
# The minimum is attained in round 252
# The minimum is attained in round 833
# The minimum is attained in round 379
# 7.935999999999998
# %
# {'bagging_fraction': 0.9720778807392004, 'boosting': 'gbdt', 'feature_fraction': 0.6998019717808699, 'lambda_l1': 4.161218952067408, 'lambda_l2': 2.1329916452635604, 'learning_rate': 0.0677844097072026, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 61
# The minimum is attained in round 60
# The minimum is attained in round 30
# The minimum is attained in round 393
# The minimum is attained in round 764
# 8.002000000000002
# %
# {'bagging_fraction': 0.9298873327400189, 'boosting': 'gbdt', 'feature_fraction': 0.5938830798053528, 'lambda_l1': 2.5411008224930582, 'lambda_l2': 6.339911048354203, 'learning_rate': 0.05067282374724051, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 338
# The minimum is attained in round 364
# The minimum is attained in round 339
# The minimum is attained in round 1444
# The minimum is attained in round 1514
# 7.934000000000004
# %
# {'bagging_fraction': 0.8196763293927759, 'boosting': 'gbdt', 'feature_fraction': 0.756926634781254, 'lambda_l1': 6.663398647801371, 'lambda_l2': 1.3741270014366487, 'learning_rate': 0.0429301950584837, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 70
# The minimum is attained in round 61
# The minimum is attained in round 44
# The minimum is attained in round 687
# The minimum is attained in round 114
# 7.986
# %
# {'bagging_fraction': 0.8625488910868988, 'boosting': 'gbdt', 'feature_fraction': 0.6366447548272688, 'lambda_l1': 0.5474914359652187, 'lambda_l2': 3.4460691142886475, 'learning_rate': 0.09566202725484102, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 104
# The minimum is attained in round 945
# The minimum is attained in round 148
# The minimum is attained in round 979
# The minimum is attained in round 1166
# 7.897999999999998
# %
# {'bagging_fraction': 0.8718165928174979, 'boosting': 'gbdt', 'feature_fraction': 0.5709890490960091, 'lambda_l1': 0.08422202117682398, 'lambda_l2': 3.375169800468284, 'learning_rate': 0.08605725970553653, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 64
# The minimum is attained in round 41
# The minimum is attained in round 72
# The minimum is attained in round 210
# The minimum is attained in round 74
# 7.977999999999999
# %
# {'bagging_fraction': 0.8000533680191736, 'boosting': 'gbdt', 'feature_fraction': 0.5195062027639112, 'lambda_l1': 0.6513664019379476, 'lambda_l2': 4.439783885247156, 'learning_rate': 0.060753364939741386, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 99
# The minimum is attained in round 242
# The minimum is attained in round 37
# The minimum is attained in round 644
# The minimum is attained in round 243
# 7.984000000000002
# %
# {'bagging_fraction': 0.8618549649806065, 'boosting': 'gbdt', 'feature_fraction': 0.8468329103195339, 'lambda_l1': 1.8271210237592297, 'lambda_l2': 5.888827180129262, 'learning_rate': 0.07739453713961796, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 119
# The minimum is attained in round 373
# The minimum is attained in round 159
# The minimum is attained in round 1508
# The minimum is attained in round 1205
# 7.9099999999999975
# %
# {'bagging_fraction': 0.833199476649219, 'boosting': 'gbdt', 'feature_fraction': 0.7299777716039172, 'lambda_l1': 2.423298523316606, 'lambda_l2': 3.393130805425366, 'learning_rate': 0.0680223059049561, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 146
# The minimum is attained in round 432
# The minimum is attained in round 582
# The minimum is attained in round 1760
# The minimum is attained in round 1106
# 7.912
# %
# {'bagging_fraction': 0.8421214633181342, 'boosting': 'gbdt', 'feature_fraction': 0.90167825805446, 'lambda_l1': 3.2057056607301906, 'lambda_l2': 2.869299727398725, 'learning_rate': 0.08044903138159296, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 80
# The minimum is attained in round 494
# The minimum is attained in round 172
# The minimum is attained in round 1043
# The minimum is attained in round 483
# 7.944
# ...
# The minimum is attained in round 227
# The minimum is attained in round 92
# The minimum is attained in round 434
# The minimum is attained in round 523
# The minimum is attained in round 145
# 7.948000000000002
# %
# {'bagging_fraction': 0.9494112978431497, 'boosting': 'gbdt', 'feature_fraction': 0.9953008946652799, 'lambda_l1': 0.33775123920759975, 'lambda_l2': 5.415346453987754, 'learning_rate': 0.025465184903636515, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 486
# The minimum is attained in round 3997
# The minimum is attained in round 586
# The minimum is attained in round 2658
# The minimum is attained in round 3060
# 7.9140000000000015
# %
# {'bagging_fraction': 0.9336917177500028, 'boosting': 'gbdt', 'feature_fraction': 0.9043244589151084, 'lambda_l1': 0.061537431158332045, 'lambda_l2': 7.526206545162166, 'learning_rate': 0.013996571413935791, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 905
# The minimum is attained in round 1389
# The minimum is attained in round 1690
# The minimum is attained in round 1947
# The minimum is attained in round 627
# 7.944
# %
# {'bagging_fraction': 0.9399372779074893, 'boosting': 'gbdt', 'feature_fraction': 0.830674978750783, 'lambda_l1': 0.6057026578310168, 'lambda_l2': 8.475306060766027, 'learning_rate': 0.032611509493924565, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 552
# The minimum is attained in round 1042
# The minimum is attained in round 858
# The minimum is attained in round 1337
# The minimum is attained in round 238
# 7.908000000000001
# %
# {'bagging_fraction': 0.9600900481692486, 'boosting': 'gbdt', 'feature_fraction': 0.9146616792263312, 'lambda_l1': 2.703127207942127, 'lambda_l2': 4.585202387736832, 'learning_rate': 0.05318512889028133, 'metric': 'binary_error', 'num_leaves': 32, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 58
# The minimum is attained in round 53
# The minimum is attained in round 37
# The minimum is attained in round 313
# The minimum is attained in round 92
# 8.017999999999999
# %
# {'bagging_fraction': 0.9256667439872344, 'boosting': 'gbdt', 'feature_fraction': 0.9551799523530158, 'lambda_l1': 2.205887678925818, 'lambda_l2': 6.768993618743956, 'learning_rate': 0.03952290185237142, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 71
# The minimum is attained in round 60
# The minimum is attained in round 51
# The minimum is attained in round 858
# The minimum is attained in round 93
# 7.996
# %
# {'bagging_fraction': 0.9930030351343642, 'boosting': 'gbdt', 'feature_fraction': 0.8758249545861257, 'lambda_l1': 2.5002788029382748, 'lambda_l2': 9.523760276895347, 'learning_rate': 0.035733517151531724, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 332
# The minimum is attained in round 943
# The minimum is attained in round 416
# The minimum is attained in round 3681
# The minimum is attained in round 2928
# 7.909999999999999
# %
# {'bagging_fraction': 0.9651409139986046, 'boosting': 'gbdt', 'feature_fraction': 0.8409241783241013, 'lambda_l1': 1.5972255047064463, 'lambda_l2': 4.138004266819378, 'learning_rate': 0.023405262314720315, 'metric': 'binary_error', 'num_leaves': 12, 'num_round': 2000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 188
# The minimum is attained in round 124
# The minimum is attained in round 648
# The minimum is attained in round 1137
# The minimum is attained in round 218
# 7.9399999999999995
# %
# {'bagging_fraction': 0.9096883077245781, 'boosting': 'gbdt', 'feature_fraction': 0.8580662294524875, 'lambda_l1': 2.9214736121677385, 'lambda_l2': 5.249463427551664, 'learning_rate': 0.030025022045634064, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 327
# The minimum is attained in round 1100
# The minimum is attained in round 621
# The minimum is attained in round 3801
# The minimum is attained in round 3019
# 7.888000000000002
# %
# {'bagging_fraction': 0.9134927683449169, 'boosting': 'gbdt', 'feature_fraction': 0.998409460770807, 'lambda_l1': 3.1107757048729514, 'lambda_l2': 7.959660463638759, 'learning_rate': 0.029496591727891007, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 405
# The minimum is attained in round 1102
# The minimum is attained in round 625
# The minimum is attained in round 3352
# The minimum is attained in round 3242
# 7.893999999999998
# %
# {'bagging_fraction': 0.9878481081782978, 'boosting': 'gbdt', 'feature_fraction': 0.9711361268224373, 'lambda_l1': 4.383200592118516, 'lambda_l2': 6.7158735056831675, 'learning_rate': 0.017627022473812606, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 650
# The minimum is attained in round 1920
# The minimum is attained in round 1459
# The minimum is attained in round 3963
# The minimum is attained in round 308
# 7.942
# %
# {'bagging_fraction': 0.9099737755738073, 'boosting': 'gbdt', 'feature_fraction': 0.8092591979464946, 'lambda_l1': 3.4264878899185303, 'lambda_l2': 8.803707007137412, 'learning_rate': 0.043390005781437105, 'metric': 'binary_error', 'num_leaves': 6, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 224
# The minimum is attained in round 187
# The minimum is attained in round 546
# The minimum is attained in round 2065
# The minimum is attained in round 2187
# 7.930000000000001
# %
# {'bagging_fraction': 0.9997977131111772, 'boosting': 'gbdt', 'feature_fraction': 0.8600547090351002, 'lambda_l1': 0.9916168787656208, 'lambda_l2': 5.93264631723932, 'learning_rate': 0.02876736434367428, 'metric': 'binary_error', 'num_leaves': 4, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 416
# The minimum is attained in round 870
# The minimum is attained in round 806
# The minimum is attained in round 2575
# The minimum is attained in round 2568
# 7.925999999999997
# %
# {'bagging_fraction': 0.9773415080555014, 'boosting': 'gbdt', 'feature_fraction': 0.8553432524105539, 'lambda_l1': 4.031430220412974, 'lambda_l2': 9.324011731999544, 'learning_rate': 0.04767428951271663, 'metric': 'binary_error', 'num_leaves': 20, 'num_round': 4000, 'num_threads': 12, 'objective': 'binary'}
# The minimum is attained in round 114
# The minimum is attained in round 59
# The minimum is attained in round 39
# The minimum is attained in round 452
# The minimum is attained in round 132
# 7.971999999999999
# %
# 100%|█████████████████████████████████████████████| 100/100 [40:54<00:00, 24.54s/trial, best loss: 0.07885999999999997]
